# %% [markdown]
# # Acoustic Token Distribution Similarity
#
# ![](ATDS.png)

# %% [markdown]
# ## Indic languages
#
# ### Target: Punjabi
#
# Data derivation walkthrough
#
# #### 1. Load in frame-wise embeddings for each audio file that have been clustered (in the various `*embeddings-clustered.parquet` files)

# %%
import ATDS

all_clusters_df = ATDS.make_all_clusters_df("indic")

all_clusters_df
# Out:
#                           wav_file  cluster_id     lang cluster_char
# 0       844424932349094-1174-m.wav         282  bengali            ļ
# 1       844424932349094-1174-m.wav         148  bengali            ¶
# 2       844424932349094-1174-m.wav         225  bengali            ă
# 3       844424932349094-1174-m.wav         389  bengali            Ƨ
# 4       844424932349094-1174-m.wav         206  bengali            ð
# ...                            ...         ...      ...          ...
# 740416  844424930470011-1158-f.wav          58  punjabi            \
# 740417  844424930470011-1158-f.wav         278  punjabi            ĸ
# 740418  844424930470011-1158-f.wav         278  punjabi            ĸ
# 740419  844424930470011-1158-f.wav         335  punjabi            ű
# 740420  844424930470011-1158-f.wav         296  punjabi            Ŋ
#
# [6838514 rows x 4 columns]

# %% [markdown]
# #### 2. Combine and deduplicate to get pseudo-text for each utterance

# %%
all_utts_df = ATDS.make_all_utts_df(all_clusters_df)

all_utts_df
# Out:
#           lang                    wav_file  \
# 0      bengali   844424930403302-711-f.wav
# 1      bengali   844424930403323-711-f.wav
# 2      bengali  844424930442076-1037-f.wav
# 3      bengali  844424930442110-1037-f.wav
# 4      bengali  844424930442118-1037-f.wav
# ...        ...                         ...
# 26262     urdu   844424932975151-264-m.wav
# 26263     urdu   844424932975913-835-m.wav
# 26264     urdu   844424932976710-264-m.wav
# 26265     urdu   844424932977992-835-m.wav
# 26266     urdu   844424932978639-264-m.wav
#
#                                             cluster_char
# 0      śƂȕŝĻUȅz+øƗĘ¥ưĪǫƄĘŶňŔǸǗǍǏǷǨB°ŁƆǸȏóúŤeèŝĩ-Äø...
# 1      śðuìn¢^tÂĆÁƗŁN5ÊȇǏǨ°ŁyØǞǀǗǸEjćǜǱĹħÝǂRȅūŢÍÈĬŮ...
# 2      ƂȕTïŅÊaI`ĭŵǭǸUȅYƗŽńůøĘŶňŗdųjȇ`ħƗǣňÂĆǣŔUƢû...
# 3      ĈƫYƕȑ+ƗŁǸŗs¼cĨȌøĘňnňŔxY*ûäøĘì¢ưîǐĪǫƄĘŶňŔǻų...
# 4      ƪ¾ăƽƹðu¢n¢ŗƼ¼ÄĦāǣŝƍǈĨáȌÑèTŔĻUYƳÈ£ȏŽúǴƟǗǸǥž&á,...
# ...                                                  ...
# 26262  ¶ă¿õëøĘŶQŃĽǝÀƗȄN5;f³¡ƹÿTŝ=aǳŎÑōŒ$ȏµáĖĜĘŶmêOÃ...
# 26263  Ù¶ăƽúKǴƟŜǸ5ǱBǬęļôǹŸŵŁNǍa;fâ`ħƄƆ¥ưƼîȎǫ|ƿ"ǠT8TŇ...
# 26264  śðŜĩX¼EŀĪƄĘŶňŅ;ǏȍÑōŔǃǮĨløȓȐǥĂþǵǿľĤȆ_ī1ǌƷÎƔpŌ...
# 26265  śŵǸǍÕǏǨB|ƣƿ"T¸ZęƖêOƆſġFæȊƖ(Ƿ.`ħƆ¥ưŴíƭŖǶļıļ...
# 26266  śŸŵǸUƙYÈĬâô´ŰÑŔ¸ŔňQŭƭJ·ČƐìŶnƱňƝȇfǎâļ´ŰƺèŝĻR...
#
# [26267 rows x 3 columns]

# %% [markdown]
# #### 3. Train sentencepiece model on target language and use model to derive tokens for all languages

# %%
all_utts_df = ATDS.train_and_encode_spm(all_utts_df, "punjabi")

all_utts_df
# Out:
#           lang                    wav_file  \
# 0      bengali   844424930403302-711-f.wav
# 1      bengali   844424930403323-711-f.wav
# 2      bengali  844424930442076-1037-f.wav
# 3      bengali  844424930442110-1037-f.wav
# 4      bengali  844424930442118-1037-f.wav
# ...        ...                         ...
# 26262     urdu   844424932975151-264-m.wav
# 26263     urdu   844424932975913-835-m.wav
# 26264     urdu   844424932976710-264-m.wav
# 26265     urdu   844424932977992-835-m.wav
# 26266     urdu   844424932978639-264-m.wav
#
#                                             cluster_char  \
# 0      śƂȕŝĻUȅz+øƗĘ¥ưĪǫƄĘŶňŔǸǗǍǏǷǨB°ŁƆǸȏóúŤeèŝĩ-Äø...
# 1      śðuìn¢^tÂĆÁƗŁN5ÊȇǏǨ°ŁyØǞǀǗǸEjćǜǱĹħÝǂRȅūŢÍÈĬŮ...
# 2      ƂȕTïŅÊaI`ĭŵǭǸUȅYƗŽńůøĘŶňŗdųjȇ`ħƗǣňÂĆǣŔUƢû...
# 3      ĈƫYƕȑ+ƗŁǸŗs¼cĨȌøĘňnňŔxY*ûäøĘì¢ưîǐĪǫƄĘŶňŔǻų...
# 4      ƪ¾ăƽƹðu¢n¢ŗƼ¼ÄĦāǣŝƍǈĨáȌÑèTŔĻUYƳÈ£ȏŽúǴƟǗǸǥž&á,...
# ...                                                  ...
# 26262  ¶ă¿õëøĘŶQŃĽǝÀƗȄN5;f³¡ƹÿTŝ=aǳŎÑōŒ$ȏµáĖĜĘŶmêOÃ...
# 26263  Ù¶ăƽúKǴƟŜǸ5ǱBǬęļôǹŸŵŁNǍa;fâ`ħƄƆ¥ưƼîȎǫ|ƿ"ǠT8TŇ...
# 26264  śðŜĩX¼EŀĪƄĘŶňŅ;ǏȍÑōŔǃǮĨløȓȐǥĂþǵǿľĤȆ_ī1ǌƷÎƔpŌ...
# 26265  śŵǸǍÕǏǨB|ƣƿ"T¸ZęƖêOƆſġFæȊƖ(Ƿ.`ħƆ¥ưŴíƭŖǶļıļ...
# 26266  śŸŵǸUƙYÈĬâô´ŰÑŔ¸ŔňQŭƭJ·ČƐìŶnƱňƝȇfǎâļ´ŰƺèŝĻR...
#
#                                            utt_piece_ids
# 0      [531, 123, 1283, 29, 305, 78, 382, 21, 96, 6, ...
# 1      [1288, 600, 264, 106, 2729, 1387, 85, 242, 546...
# 2      [4749, 286, 820, 217, 370, 72, 146, 825, 667, ...
# 3      [150, 314, 792, 1118, 361, 259, 29, 6988, 223,...
# 4      [195, 39, 467, 5492, 26, 8, 26, 2517, 84, 151,...
# ...                                                  ...
# 26262  [326, 224, 269, 189, 109, 1363, 8102, 981, 78,...
# 26263  [1589, 98, 467, 2993, 5111, 85, 5510, 515, 56,...
# 26264  [1486, 736, 84, 577, 1, 539, 420, 851, 327, 10...
# 26265  [2144, 3253, 562, 601, 321, 73, 167, 322, 8706...
# 26266  [4257, 3059, 1141, 115, 435, 512, 358, 508, 98...
#
# [26267 rows x 4 columns]

# %% [markdown]
# #### 4. Derive token frequencies for each language (1.0 = most frequent within each language/column)

# %%
piece_freqs_matrix = ATDS.make_piece_freqs_matrix(all_utts_df, "punjabi")

piece_freqs_matrix
# Out:
# lang            punjabi   bengali  gujarati     hindi  malayalam   marathi  \
# utt_piece_ids
# 1              1.000000  1.000000  1.000000  1.000000   0.795799  0.691673
# 2              0.946369  0.443672  0.995691  0.965529   0.845628  1.000000
# 3              0.640968  0.284809  0.478311  0.665135   0.767465  0.353818
# 4              0.633892  0.340217  0.666475  0.446159   0.743039  0.478585
# 5              0.614153  0.464936  0.521689  0.613263   0.869565  0.398510
# ...                 ...       ...       ...       ...        ...       ...
# 9991           0.000745  0.000000  0.000000  0.000000   0.000000  0.000000
# 9992           0.000745  0.000000  0.000000  0.000000   0.000000  0.000000
# 9993           0.000745  0.000000  0.000000  0.000000   0.000000  0.000000
# 9994           0.000745  0.001022  0.000575  0.000985   0.000000  0.000000
# 9995           0.000372  0.002862  0.000287  0.000985   0.003908  0.001862
#
# lang               odia     tamil      urdu
# utt_piece_ids
# 1              1.000000  0.474374  1.000000
# 2              0.906939  0.745195  0.876662
# 3              0.435302  0.616482  0.472025
# 4              0.668073  0.481654  0.463060
# 5              0.238631  0.574549  0.801546
# ...                 ...       ...       ...
# 9991           0.000000  0.000000  0.000000
# 9992           0.000000  0.000000  0.000000
# 9993           0.000000  0.000000  0.000000
# 9994           0.003282  0.000000  0.000000
# 9995           0.000938  0.000000  0.000927
#
# [9995 rows x 9 columns]

# %% [markdown]
# #### 5. Get pair-wise similarities using consine similarity between each language vector

# %%
ATDS_matrix = ATDS.make_ATDS_matrix(piece_freqs_matrix)

ATDS_matrix
# Out:
#     ref_lang   punjabi   bengali  gujarati     hindi malayalam   marathi  \
# 0    punjabi       NaN   0.89834   0.92537  0.960345  0.889211  0.917747
# 0    bengali  0.898340      None  0.915768  0.912807  0.837936  0.883071
# 0   gujarati  0.925370  0.915768      None  0.937169  0.871127  0.942984
# 0      hindi  0.960345  0.912807  0.937169      None  0.876207  0.936571
# 0  malayalam  0.889211  0.837936  0.871127  0.876207      None  0.887913
# 0    marathi  0.917747  0.883071  0.942984  0.936571  0.887913      None
# 0       odia  0.867011  0.907864  0.936393     0.882  0.838508  0.908061
# 0      tamil  0.855450   0.81156  0.876194  0.856358   0.90777  0.881482
# 0       urdu  0.926529  0.886872   0.89494  0.958859  0.881012  0.922264
#
#        odia     tamil      urdu
# 0  0.867011   0.85545  0.926529
# 0  0.907864   0.81156  0.886872
# 0  0.936393  0.876194   0.89494
# 0     0.882  0.856358  0.958859
# 0  0.838508   0.90777  0.881012
# 0  0.908061  0.881482  0.922264
# 0      None  0.868832  0.852086
# 0  0.868832      None  0.826908
# 0  0.852086  0.826908      None

# %% [markdown]
# #### 6. Get best donors for target language (ATDS in descending order)

# %%
best_donors_for_punjabi = ATDS.get_best_donors_by_ATDS(ATDS_matrix, "punjabi")

# Write out indic similarities for comparison with SpeechBrain and lang2vec similarities
best_donors_for_punjabi.to_csv("/workspace/data/artefacts/ATDS/indic_atds.csv", index=False)

best_donors_for_punjabi
# Out:
#    target_lang donor_lang  atds
# 27     punjabi      hindi  0.96
# 72     punjabi       urdu  0.93
# 18     punjabi   gujarati  0.93
# 45     punjabi    marathi  0.92
# 9      punjabi    bengali  0.90
# 36     punjabi  malayalam  0.89
# 54     punjabi       odia  0.87
# 63     punjabi      tamil  0.86

# %% [markdown]
# ## Other targets
#
# ### Galician

# %%
west_iberian_atds_matrix, best_donors_for_galician = ATDS.run_all("west-iberian", "galician")

best_donors_for_galician
# Out:
#   target_lang  donor_lang  atds
# 6    galician     spanish  0.96
# 3    galician  portuguese  0.89

# %% [markdown]
# ### Iban

# %%
malayic_atds_matrix, best_donors_for_iban = ATDS.run_all("malayic", "iban")

best_donors_for_iban
# Out:
#   target_lang  donor_lang  atds
# 6        iban       malay  0.91
# 3        iban  indonesian  0.88

# %% [markdown]
# ### Setswana

# %%
sotho_tswana_atds_matrix, best_donors_for_setswana = ATDS.run_all("sotho-tswana", "setswana")

best_donors_for_setswana
# Out:
#   target_lang donor_lang  atds
# 6    setswana    sesotho  0.96
# 3    setswana     sepedi  0.88
