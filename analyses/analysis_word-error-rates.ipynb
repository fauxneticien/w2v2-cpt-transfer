# %%
import jiwer
import pandas as pd

from pathlib import Path

# %% [markdown]
# List all reference files (generated by `/fairseq/blob/main/examples/speech_recognition/infer.py`)

# %%
asr_results_refs = sorted(list(Path("/workspace/data/artefacts/asr-results").glob("*/ref.word-*.txt")))

asr_results_refs[:10]
# Out:
# [PosixPath('/workspace/data/artefacts/asr-results/galician/ref.word-xls-r_cpt-galician-10h_ft-gl-1h.pt-test.txt'),
#  PosixPath('/workspace/data/artefacts/asr-results/galician/ref.word-xls-r_cpt-galician-10h_portuguese-60h_ft-gl-1h.pt-test.txt'),
#  PosixPath('/workspace/data/artefacts/asr-results/galician/ref.word-xls-r_cpt-galician-10h_spanish-60h_ft-gl-1h.pt-test.txt'),
#  PosixPath('/workspace/data/artefacts/asr-results/galician/ref.word-xlsr2_300m_ft-gl-1h.pt-test.txt'),
#  PosixPath('/workspace/data/artefacts/asr-results/iban/ref.word-xls-r_cpt_iban-7h_ft-iba-1h.pt-test.txt'),
#  PosixPath('/workspace/data/artefacts/asr-results/iban/ref.word-xls-r_cpt_iban-7h_indonesian-60h_ft-iba-1h.pt-test.txt'),
#  PosixPath('/workspace/data/artefacts/asr-results/iban/ref.word-xls-r_cpt_iban-7h_malay-60h_ft-iba-1h.pt-test.txt'),
#  PosixPath('/workspace/data/artefacts/asr-results/iban/ref.word-xls-r_ft-iba-1h.pt-test.txt'),
#  PosixPath('/workspace/data/artefacts/asr-results/punjabi/ref.word-xls-r_cpt_punjabi-10h_10k_ft-pa-1h.pt-test-2h.txt'),
#  PosixPath('/workspace/data/artefacts/asr-results/punjabi/ref.word-xls-r_cpt_punjabi-10h_bengali-60h-seed-1_ft-pa-1h.pt-test-2h.txt')]

# %% [markdown]
# Each reference line consists of the text, and a speaker-utterance ID `(None-1234)` (speaker is `None` since we didn't provide any speaker info)

# %%
# !head /workspace/data/artefacts/asr-results/galician/ref.word-xls-r_cpt-galician-10h_ft-gl-1h.pt-test.txt
# Out:
# a organización política ou estrutura constitucional que caracteriza unha federación coñécese como federalismo (None-1286)
# nalgúns países existen placas provisionais mentres non se completaron os trámites de matriculación (None-3334)
# nas publicacións coincidían exiliados de diferentes ideoloxías que fuxían do conformismo e do folclorismo (None-4953)
# a estrela de seis puntas representa o seis condados de irlanda do norte (None-1785)
# úsase como alternativa para mulleres sensibles ó estróxeno (None-281)
# estes sistemas xurdiron das tradicións anteriores dos sistemas de símbolos nos primeiros tempos neolíticos (None-5314)
# completamente incomodado amadeo tornou a torino onde recibiu o título de duque de aosta (None-2816)
# saliéntase a construción de templos e hipoxeos (None-6617)
# a súa cerámica estaba pouco decorada (None-2439)
# o escocés tivo a oportunidade de pilotar o monopraza durante varios adestramentos libres (None-2648)

# %% [markdown]
# Gather both reference and hypotheses (one for each fine-tuned model) into a single data frame:

# %%
all_eval_dfs = []

for ref_txt in asr_results_refs:
    hyp_txt = str(ref_txt).replace("ref.", "hypo.")
    
    with open(ref_txt) as r, open(hyp_txt) as h:
        ref_lines = [ l.replace(")\n", "").split(" (None-") for l in r.readlines() ]
        hyp_lines = [ l.replace(")\n", "").split(" (None-") for l in h.readlines() ]
        
    ref_df = pd.DataFrame(ref_lines, columns=["ref_text", "utt_id"])
    hyp_df = pd.DataFrame(hyp_lines, columns=["hyp_text", "utt_id"])
    
    checkpoint_name = ref_txt.name.split(".pt")[0].replace("ref.word-", "")
    
    eval_df = ref_df.merge(hyp_df, how='left').assign(checkpoint=checkpoint_name)
    
    all_eval_dfs.append(eval_df)
    
all_eval_dfs = pd.concat(all_eval_dfs)

all_eval_dfs
# Out:
#                                                ref_text utt_id  \
# 0     a organización política ou estrutura constituc...   1286
# 1     nalgúns países existen placas provisionais men...   3334
# 2     nas publicacións coincidían exiliados de difer...   4953
# 3     a estrela de seis puntas representa o seis con...   1785
# 4     úsase como alternativa para mulleres sensibles...    281
# ...                                                 ...    ...
# 2083                                               kedi    846
# 2084                                              sport   1069
# 2085                                                neo   1854
# 2086                                             tirelo    558
# 2087                                                ron    927
#
#                                                hyp_text  \
# 0     a organización política ou estrutura constituc...
# 1     nalgúns países existen placas provisionais men...
# 2     nas publicacións coincidían exiliados de difer...
# 3     a estrela de seis puntas representa os seis co...
# 4     úsase como alternativa para mulleres sensibles...
# ...                                                 ...
# 2083                                               kedi
# 2084                                              sport
# 2085                                                neo
# 2086                                             tirelo
# 2087                                                ron
#
#                            checkpoint
# 0     xls-r_cpt-galician-10h_ft-gl-1h
# 1     xls-r_cpt-galician-10h_ft-gl-1h
# 2     xls-r_cpt-galician-10h_ft-gl-1h
# 3     xls-r_cpt-galician-10h_ft-gl-1h
# 4     xls-r_cpt-galician-10h_ft-gl-1h
# ...                               ...
# 2083                  xls-r_ft-tsn-1h
# 2084                  xls-r_ft-tsn-1h
# 2085                  xls-r_ft-tsn-1h
# 2086                  xls-r_ft-tsn-1h
# 2087                  xls-r_ft-tsn-1h
#
# [73328 rows x 4 columns]

# %% [markdown]
# Calculate per-checkpoint word error rates

# %%
wer_df = pd.concat([
    pd.DataFrame({
        'checkpoint' : [ cp_name ],
        'test_wer' : jiwer.wer(eval_data.ref_text.to_list(), eval_data.hyp_text.to_list())
    }) for cp_name, eval_data in all_eval_dfs.groupby('checkpoint')
]).reset_index(drop=True)

wer_df
# Out:
#                                            checkpoint  test_wer
# 0                     xls-r_cpt-galician-10h_ft-gl-1h  0.149782
# 1      xls-r_cpt-galician-10h_portuguese-60h_ft-gl-1h  0.139209
# 2         xls-r_cpt-galician-10h_spanish-60h_ft-gl-1h  0.137354
# 3                         xls-r_cpt_iban-7h_ft-iba-1h  0.166334
# 4          xls-r_cpt_iban-7h_indonesian-60h_ft-iba-1h  0.164337
# 5               xls-r_cpt_iban-7h_malay-60h_ft-iba-1h  0.158698
# 6                  xls-r_cpt_punjabi-10h_10k_ft-pa-1h  0.249594
# 7   xls-r_cpt_punjabi-10h_bengali-60h-seed-1_ft-pa-1h  0.250503
# 8   xls-r_cpt_punjabi-10h_bengali-60h-seed-2_ft-pa-1h  0.251800
# 9   xls-r_cpt_punjabi-10h_bengali-60h-seed-3_ft-pa-1h  0.251865
# 10  xls-r_cpt_punjabi-10h_gujarati-60h-seed-1_ft-p...  0.244209
# 11  xls-r_cpt_punjabi-10h_gujarati-60h-seed-2_ft-p...  0.244080
# 12  xls-r_cpt_punjabi-10h_gujarati-60h-seed-3_ft-p...  0.242004
# 13    xls-r_cpt_punjabi-10h_hindi-60h-seed-1_ft-pa-1h  0.234413
# 14    xls-r_cpt_punjabi-10h_hindi-60h-seed-2_ft-pa-1h  0.238046
# 15    xls-r_cpt_punjabi-10h_hindi-60h-seed-3_ft-pa-1h  0.235126
# 16  xls-r_cpt_punjabi-10h_malayalam-60h-seed-1_ft-...  0.250827
# 17  xls-r_cpt_punjabi-10h_malayalam-60h-seed-2_ft-...  0.252514
# 18  xls-r_cpt_punjabi-10h_malayalam-60h-seed-3_ft-...  0.249919
# 19  xls-r_cpt_punjabi-10h_marathi-60h-seed-1_ft-pa-1h  0.245767
# 20  xls-r_cpt_punjabi-10h_marathi-60h-seed-2_ft-pa-1h  0.247259
# 21  xls-r_cpt_punjabi-10h_marathi-60h-seed-3_ft-pa-1h  0.245118
# 22     xls-r_cpt_punjabi-10h_odia-60h-seed-1_ft-pa-1h  0.250308
# 23     xls-r_cpt_punjabi-10h_odia-60h-seed-2_ft-pa-1h  0.252190
# 24     xls-r_cpt_punjabi-10h_odia-60h-seed-3_ft-pa-1h  0.249854
# 25    xls-r_cpt_punjabi-10h_tamil-60h-seed-1_ft-pa-1h  0.250762
# 26    xls-r_cpt_punjabi-10h_tamil-60h-seed-2_ft-pa-1h  0.249984
# 27    xls-r_cpt_punjabi-10h_tamil-60h-seed-3_ft-pa-1h  0.253812
# 28     xls-r_cpt_punjabi-10h_urdu-60h-seed-1_ft-pa-1h  0.243171
# 29     xls-r_cpt_punjabi-10h_urdu-60h-seed-2_ft-pa-1h  0.244274
# 30     xls-r_cpt_punjabi-10h_urdu-60h-seed-3_ft-pa-1h  0.244923
# 31                 xls-r_cpt_punjabi-70h_10k_ft-pa-1h  0.222150
# 32                   xls-r_cpt_setswana-10h_ft-tsn-1h  0.125713
# 33        xls-r_cpt_setswana-10h_sepedi-56h_ft-tsn-1h  0.119512
# 34       xls-r_cpt_setswana-10h_sesotho-56h_ft-tsn-1h  0.115812
# 35                                    xls-r_ft-iba-1h  0.213556
# 36                                    xls-r_ft-tsn-1h  0.208321
# 37                                xlsr2_300m_ft-gl-1h  0.154093
# 38                                xlsr2_300m_ft-pa-1h  0.308181

# %%
def parse_cpt_data(checkpoint_str):
    if not "cpt" in checkpoint_str:
        return "N/A"
    else:
        return checkpoint_str.replace("xls-r_cpt_", "").replace("xls-r_cpt-", "").split("_ft-")[0]

lang_mapping = {
    # ft-X-1h = fine-tuned on 1 hour of target language
    'ft-gl-1h': "Galician",
    "ft-iba-1h": "Iban",
    "ft-pa-1h" : "Punjabi",
    "ft-tsn-1h": "Setswana"
}

wer_df["target_lang"] = [ lang_mapping[l] for l in wer_df.checkpoint.str.extract("(ft-gl-1h|ft-iba-1h|ft-pa-1h|ft-tsn-1h)")[0] ]

wer_df["CPT"] = wer_df.checkpoint.str.contains("cpt")

wer_df["CPT_data"] = wer_df.checkpoint.apply(parse_cpt_data).str.replace("_\d+k", "", regex=True)

wer_df = wer_df.sort_values(['target_lang', 'CPT']).reset_index(drop=True)

wer_df
# Out:
#                                            checkpoint  test_wer target_lang  \
# 0                                 xlsr2_300m_ft-gl-1h  0.154093    Galician
# 1                     xls-r_cpt-galician-10h_ft-gl-1h  0.149782    Galician
# 2      xls-r_cpt-galician-10h_portuguese-60h_ft-gl-1h  0.139209    Galician
# 3         xls-r_cpt-galician-10h_spanish-60h_ft-gl-1h  0.137354    Galician
# 4                                     xls-r_ft-iba-1h  0.213556        Iban
# 5                         xls-r_cpt_iban-7h_ft-iba-1h  0.166334        Iban
# 6          xls-r_cpt_iban-7h_indonesian-60h_ft-iba-1h  0.164337        Iban
# 7               xls-r_cpt_iban-7h_malay-60h_ft-iba-1h  0.158698        Iban
# 8                                 xlsr2_300m_ft-pa-1h  0.308181     Punjabi
# 9                  xls-r_cpt_punjabi-10h_10k_ft-pa-1h  0.249594     Punjabi
# 10  xls-r_cpt_punjabi-10h_bengali-60h-seed-1_ft-pa-1h  0.250503     Punjabi
# 11  xls-r_cpt_punjabi-10h_bengali-60h-seed-2_ft-pa-1h  0.251800     Punjabi
# 12  xls-r_cpt_punjabi-10h_bengali-60h-seed-3_ft-pa-1h  0.251865     Punjabi
# 13  xls-r_cpt_punjabi-10h_gujarati-60h-seed-1_ft-p...  0.244209     Punjabi
# 14  xls-r_cpt_punjabi-10h_gujarati-60h-seed-2_ft-p...  0.244080     Punjabi
# 15  xls-r_cpt_punjabi-10h_gujarati-60h-seed-3_ft-p...  0.242004     Punjabi
# 16    xls-r_cpt_punjabi-10h_hindi-60h-seed-1_ft-pa-1h  0.234413     Punjabi
# 17    xls-r_cpt_punjabi-10h_hindi-60h-seed-2_ft-pa-1h  0.238046     Punjabi
# 18    xls-r_cpt_punjabi-10h_hindi-60h-seed-3_ft-pa-1h  0.235126     Punjabi
# 19  xls-r_cpt_punjabi-10h_malayalam-60h-seed-1_ft-...  0.250827     Punjabi
# 20  xls-r_cpt_punjabi-10h_malayalam-60h-seed-2_ft-...  0.252514     Punjabi
# 21  xls-r_cpt_punjabi-10h_malayalam-60h-seed-3_ft-...  0.249919     Punjabi
# 22  xls-r_cpt_punjabi-10h_marathi-60h-seed-1_ft-pa-1h  0.245767     Punjabi
# 23  xls-r_cpt_punjabi-10h_marathi-60h-seed-2_ft-pa-1h  0.247259     Punjabi
# 24  xls-r_cpt_punjabi-10h_marathi-60h-seed-3_ft-pa-1h  0.245118     Punjabi
# 25     xls-r_cpt_punjabi-10h_odia-60h-seed-1_ft-pa-1h  0.250308     Punjabi
# 26     xls-r_cpt_punjabi-10h_odia-60h-seed-2_ft-pa-1h  0.252190     Punjabi
# 27     xls-r_cpt_punjabi-10h_odia-60h-seed-3_ft-pa-1h  0.249854     Punjabi
# 28    xls-r_cpt_punjabi-10h_tamil-60h-seed-1_ft-pa-1h  0.250762     Punjabi
# 29    xls-r_cpt_punjabi-10h_tamil-60h-seed-2_ft-pa-1h  0.249984     Punjabi
# 30    xls-r_cpt_punjabi-10h_tamil-60h-seed-3_ft-pa-1h  0.253812     Punjabi
# 31     xls-r_cpt_punjabi-10h_urdu-60h-seed-1_ft-pa-1h  0.243171     Punjabi
# 32     xls-r_cpt_punjabi-10h_urdu-60h-seed-2_ft-pa-1h  0.244274     Punjabi
# 33     xls-r_cpt_punjabi-10h_urdu-60h-seed-3_ft-pa-1h  0.244923     Punjabi
# 34                 xls-r_cpt_punjabi-70h_10k_ft-pa-1h  0.222150     Punjabi
# 35                                    xls-r_ft-tsn-1h  0.208321    Setswana
# 36                   xls-r_cpt_setswana-10h_ft-tsn-1h  0.125713    Setswana
# 37        xls-r_cpt_setswana-10h_sepedi-56h_ft-tsn-1h  0.119512    Setswana
# 38       xls-r_cpt_setswana-10h_sesotho-56h_ft-tsn-1h  0.115812    Setswana
#
#       CPT                          CPT_data
# 0   False                               N/A
# 1    True                      galician-10h
# 2    True       galician-10h_portuguese-60h
# 3    True          galician-10h_spanish-60h
# 4   False                               N/A
# 5    True                           iban-7h
# 6    True            iban-7h_indonesian-60h
# 7    True                 iban-7h_malay-60h
# 8   False                               N/A
# 9    True                       punjabi-10h
# 10   True    punjabi-10h_bengali-60h-seed-1
# 11   True    punjabi-10h_bengali-60h-seed-2
# 12   True    punjabi-10h_bengali-60h-seed-3
# 13   True   punjabi-10h_gujarati-60h-seed-1
# 14   True   punjabi-10h_gujarati-60h-seed-2
# 15   True   punjabi-10h_gujarati-60h-seed-3
# 16   True      punjabi-10h_hindi-60h-seed-1
# 17   True      punjabi-10h_hindi-60h-seed-2
# 18   True      punjabi-10h_hindi-60h-seed-3
# 19   True  punjabi-10h_malayalam-60h-seed-1
# 20   True  punjabi-10h_malayalam-60h-seed-2
# 21   True  punjabi-10h_malayalam-60h-seed-3
# 22   True    punjabi-10h_marathi-60h-seed-1
# 23   True    punjabi-10h_marathi-60h-seed-2
# 24   True    punjabi-10h_marathi-60h-seed-3
# 25   True       punjabi-10h_odia-60h-seed-1
# 26   True       punjabi-10h_odia-60h-seed-2
# 27   True       punjabi-10h_odia-60h-seed-3
# 28   True      punjabi-10h_tamil-60h-seed-1
# 29   True      punjabi-10h_tamil-60h-seed-2
# 30   True      punjabi-10h_tamil-60h-seed-3
# 31   True       punjabi-10h_urdu-60h-seed-1
# 32   True       punjabi-10h_urdu-60h-seed-2
# 33   True       punjabi-10h_urdu-60h-seed-3
# 34   True                       punjabi-70h
# 35  False                               N/A
# 36   True                      setswana-10h
# 37   True           setswana-10h_sepedi-56h
# 38   True          setswana-10h_sesotho-56h

# %% [markdown]
# Compile Punjabi ASR results (multiple seeds per donor)

# %%
def get_werr_df(target_df, baseline):
    baseline_wer = round(target_df[ target_df.checkpoint == baseline ].test_wer.to_list()[0] * 100, 1)

    target_df["percent_wer"] = round(target_df.test_wer * 100, 1)

    target_df["percent_werr"] = round((baseline_wer - target_df.percent_wer)/baseline_wer * 100, 1)

    return target_df

# %%
punjabi_werr = get_werr_df(wer_df[wer_df.target_lang == "Punjabi"].copy(), "xls-r_cpt_punjabi-10h_10k_ft-pa-1h")

# Write out indic werrs for calculating correlations with similarity measures
punjabi_werr[ punjabi_werr.CPT_data.str.contains("seed") ].to_csv("/workspace/data/artefacts/ATDS/indic_werr.csv", index=False)

punjabi_werr
# Out:
#                                            checkpoint  test_wer target_lang  \
# 8                                 xlsr2_300m_ft-pa-1h  0.308181     Punjabi
# 9                  xls-r_cpt_punjabi-10h_10k_ft-pa-1h  0.249594     Punjabi
# 10  xls-r_cpt_punjabi-10h_bengali-60h-seed-1_ft-pa-1h  0.250503     Punjabi
# 11  xls-r_cpt_punjabi-10h_bengali-60h-seed-2_ft-pa-1h  0.251800     Punjabi
# 12  xls-r_cpt_punjabi-10h_bengali-60h-seed-3_ft-pa-1h  0.251865     Punjabi
# 13  xls-r_cpt_punjabi-10h_gujarati-60h-seed-1_ft-p...  0.244209     Punjabi
# 14  xls-r_cpt_punjabi-10h_gujarati-60h-seed-2_ft-p...  0.244080     Punjabi
# 15  xls-r_cpt_punjabi-10h_gujarati-60h-seed-3_ft-p...  0.242004     Punjabi
# 16    xls-r_cpt_punjabi-10h_hindi-60h-seed-1_ft-pa-1h  0.234413     Punjabi
# 17    xls-r_cpt_punjabi-10h_hindi-60h-seed-2_ft-pa-1h  0.238046     Punjabi
# 18    xls-r_cpt_punjabi-10h_hindi-60h-seed-3_ft-pa-1h  0.235126     Punjabi
# 19  xls-r_cpt_punjabi-10h_malayalam-60h-seed-1_ft-...  0.250827     Punjabi
# 20  xls-r_cpt_punjabi-10h_malayalam-60h-seed-2_ft-...  0.252514     Punjabi
# 21  xls-r_cpt_punjabi-10h_malayalam-60h-seed-3_ft-...  0.249919     Punjabi
# 22  xls-r_cpt_punjabi-10h_marathi-60h-seed-1_ft-pa-1h  0.245767     Punjabi
# 23  xls-r_cpt_punjabi-10h_marathi-60h-seed-2_ft-pa-1h  0.247259     Punjabi
# 24  xls-r_cpt_punjabi-10h_marathi-60h-seed-3_ft-pa-1h  0.245118     Punjabi
# 25     xls-r_cpt_punjabi-10h_odia-60h-seed-1_ft-pa-1h  0.250308     Punjabi
# 26     xls-r_cpt_punjabi-10h_odia-60h-seed-2_ft-pa-1h  0.252190     Punjabi
# 27     xls-r_cpt_punjabi-10h_odia-60h-seed-3_ft-pa-1h  0.249854     Punjabi
# 28    xls-r_cpt_punjabi-10h_tamil-60h-seed-1_ft-pa-1h  0.250762     Punjabi
# 29    xls-r_cpt_punjabi-10h_tamil-60h-seed-2_ft-pa-1h  0.249984     Punjabi
# 30    xls-r_cpt_punjabi-10h_tamil-60h-seed-3_ft-pa-1h  0.253812     Punjabi
# 31     xls-r_cpt_punjabi-10h_urdu-60h-seed-1_ft-pa-1h  0.243171     Punjabi
# 32     xls-r_cpt_punjabi-10h_urdu-60h-seed-2_ft-pa-1h  0.244274     Punjabi
# 33     xls-r_cpt_punjabi-10h_urdu-60h-seed-3_ft-pa-1h  0.244923     Punjabi
# 34                 xls-r_cpt_punjabi-70h_10k_ft-pa-1h  0.222150     Punjabi
#
#       CPT                          CPT_data  percent_wer  percent_werr
# 8   False                               N/A         30.8         -23.2
# 9    True                       punjabi-10h         25.0           0.0
# 10   True    punjabi-10h_bengali-60h-seed-1         25.1          -0.4
# 11   True    punjabi-10h_bengali-60h-seed-2         25.2          -0.8
# 12   True    punjabi-10h_bengali-60h-seed-3         25.2          -0.8
# 13   True   punjabi-10h_gujarati-60h-seed-1         24.4           2.4
# 14   True   punjabi-10h_gujarati-60h-seed-2         24.4           2.4
# 15   True   punjabi-10h_gujarati-60h-seed-3         24.2           3.2
# 16   True      punjabi-10h_hindi-60h-seed-1         23.4           6.4
# 17   True      punjabi-10h_hindi-60h-seed-2         23.8           4.8
# 18   True      punjabi-10h_hindi-60h-seed-3         23.5           6.0
# 19   True  punjabi-10h_malayalam-60h-seed-1         25.1          -0.4
# 20   True  punjabi-10h_malayalam-60h-seed-2         25.3          -1.2
# 21   True  punjabi-10h_malayalam-60h-seed-3         25.0           0.0
# 22   True    punjabi-10h_marathi-60h-seed-1         24.6           1.6
# 23   True    punjabi-10h_marathi-60h-seed-2         24.7           1.2
# 24   True    punjabi-10h_marathi-60h-seed-3         24.5           2.0
# 25   True       punjabi-10h_odia-60h-seed-1         25.0           0.0
# 26   True       punjabi-10h_odia-60h-seed-2         25.2          -0.8
# 27   True       punjabi-10h_odia-60h-seed-3         25.0           0.0
# 28   True      punjabi-10h_tamil-60h-seed-1         25.1          -0.4
# 29   True      punjabi-10h_tamil-60h-seed-2         25.0           0.0
# 30   True      punjabi-10h_tamil-60h-seed-3         25.4          -1.6
# 31   True       punjabi-10h_urdu-60h-seed-1         24.3           2.8
# 32   True       punjabi-10h_urdu-60h-seed-2         24.4           2.4
# 33   True       punjabi-10h_urdu-60h-seed-3         24.5           2.0
# 34   True                       punjabi-70h         22.2          11.2

# %%
punjabi_werr_donors = punjabi_werr[ punjabi_werr.CPT_data.str.contains("seed") ].copy()

punjabi_werr_donors.CPT_data = punjabi_werr_donors.CPT_data.str.replace("-seed-\d", "", regex=True)

punjabi_werr_donors.groupby('CPT_data').agg(
        median_wer = ('percent_wer', 'median'),
        median_werr = ('percent_werr', 'median'),
        min_wer = ('percent_wer', 'min'),
        max_wer = ('percent_wer', 'max')
    ).reset_index() \
    .append(punjabi_werr[ ~punjabi_werr.CPT_data.str.contains("seed") ][["CPT_data", "percent_wer", "percent_werr"]].rename(columns={'percent_wer':'median_wer', 'percent_werr':'median_werr'})) \
    .fillna("") \
    .sort_values(['median_wer', 'max_wer'], ascending=[True, False])
# Out:
#                      CPT_data  median_wer  median_werr min_wer max_wer
# 34                punjabi-70h        22.2         11.2
# 2       punjabi-10h_hindi-60h        23.5          6.0    23.4    23.8
# 7        punjabi-10h_urdu-60h        24.4          2.4    24.3    24.5
# 1    punjabi-10h_gujarati-60h        24.4          2.4    24.2    24.4
# 4     punjabi-10h_marathi-60h        24.6          1.6    24.5    24.7
# 9                 punjabi-10h        25.0          0.0
# 5        punjabi-10h_odia-60h        25.0          0.0    25.0    25.2
# 6       punjabi-10h_tamil-60h        25.1         -0.4    25.0    25.4
# 3   punjabi-10h_malayalam-60h        25.1         -0.4    25.0    25.3
# 0     punjabi-10h_bengali-60h        25.2         -0.8    25.1    25.2
# 8                         N/A        30.8        -23.2

# %%
get_werr_df(wer_df[wer_df.target_lang == "Galician"].copy(), "xls-r_cpt-galician-10h_ft-gl-1h").sort_values('percent_wer')
# Out:
#                                        checkpoint  test_wer target_lang  \
# 3     xls-r_cpt-galician-10h_spanish-60h_ft-gl-1h  0.137354    Galician
# 2  xls-r_cpt-galician-10h_portuguese-60h_ft-gl-1h  0.139209    Galician
# 1                 xls-r_cpt-galician-10h_ft-gl-1h  0.149782    Galician
# 0                             xlsr2_300m_ft-gl-1h  0.154093    Galician
#
#      CPT                     CPT_data  percent_wer  percent_werr
# 3   True     galician-10h_spanish-60h         13.7           8.7
# 2   True  galician-10h_portuguese-60h         13.9           7.3
# 1   True                 galician-10h         15.0           0.0
# 0  False                          N/A         15.4          -2.7

# %%
get_werr_df(wer_df[wer_df.target_lang == "Iban"].copy(), "xls-r_cpt_iban-7h_ft-iba-1h").sort_values('percent_wer')
# Out:
#                                    checkpoint  test_wer target_lang    CPT  \
# 7       xls-r_cpt_iban-7h_malay-60h_ft-iba-1h  0.158698        Iban   True
# 6  xls-r_cpt_iban-7h_indonesian-60h_ft-iba-1h  0.164337        Iban   True
# 5                 xls-r_cpt_iban-7h_ft-iba-1h  0.166334        Iban   True
# 4                             xls-r_ft-iba-1h  0.213556        Iban  False
#
#                  CPT_data  percent_wer  percent_werr
# 7       iban-7h_malay-60h         15.9           4.2
# 6  iban-7h_indonesian-60h         16.4           1.2
# 5                 iban-7h         16.6           0.0
# 4                     N/A         21.4         -28.9

# %%
get_werr_df(wer_df[wer_df.target_lang == "Setswana"].copy(), "xls-r_cpt_setswana-10h_ft-tsn-1h").sort_values('percent_wer')
# Out:
#                                       checkpoint  test_wer target_lang    CPT  \
# 38  xls-r_cpt_setswana-10h_sesotho-56h_ft-tsn-1h  0.115812    Setswana   True
# 37   xls-r_cpt_setswana-10h_sepedi-56h_ft-tsn-1h  0.119512    Setswana   True
# 36              xls-r_cpt_setswana-10h_ft-tsn-1h  0.125713    Setswana   True
# 35                               xls-r_ft-tsn-1h  0.208321    Setswana  False
#
#                     CPT_data  percent_wer  percent_werr
# 38  setswana-10h_sesotho-56h         11.6           7.9
# 37   setswana-10h_sepedi-56h         12.0           4.8
# 36              setswana-10h         12.6           0.0
# 35                       N/A         20.8         -65.1
